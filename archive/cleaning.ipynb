# %% [markdown]
# ## Cleaning notebook
#
# Tasks:
# 1. Checking on the outputs produced by the scraping class and the GUI.
# 2. Sanity checking final clean data and feature engineering process before sending to final clean state.

# %%
import pandas as pd

# %%
raw = pd.read_csv('raw_data/SE_jobsFri_Nov_20_11:33:31_2020.csv', index_col=0)
raw
# Out:
#                                                company  \
# 0                            Falmouth Launchpad-London
# 1    Rise Technical Recruitment Limited19 reviews-L...
# 2                             Travelfusion-London EC3A
# 3       Legal Marketing Services-Sutton and Manor CH65
# 4                    Lewisham Council42 reviews-London
# ..                                                 ...
# 495                                 Spectrum IT-London
# 496                               Reqiva Ltd-Wokingham
# 497                 Lawrence Harvey-Bishop's Stortford
# 498                  The Candidate2 reviews-Home Based
# 499                                   Oho Group-London
#
#                                         job_title  \
# 0                              Software Developer
# 1                 Software Developer (Typescript)
# 2                         Java Software Developer
# 3                  React Software Developer @ LMS
# ...

# %%
raw.job_descr.nunique()
# Out:
# 498

# %%
raw.company.apply(get_location)
# Out:
# 0                  London
# 1                  London
# 2                  London
# 3        Sutton and Manor
# 4                  London
#               ...
# 495                London
# 496             Wokingham
# 497    Bishop's Stortford
# 498            Home Based
# 499                London
# Name: company, Length: 500, dtype: object

# %%
clean_SE = pd.read_csv('../clean_data/SE_jobs_CLEAN.csv', index_col=0)
clean_SE.head()
# Out:
#                               company  \
# 0                  Falmouth Launchpad
# 1  Rise Technical Recruitment Limited
# 2                        Travelfusion
# 3            Legal Marketing Services
# 4                    Lewisham Council
#
#                                       job_title  \
# 0                            Software Developer
# 1               Software Developer (Typescript)
# 2                       Java Software Developer
# 3                React Software Developer @ LMS
# 4  Software Developer Apprentice - TransferWise
#
#                                            job_descr  \
# 0  are changing time this amazing time technology...
# 1  Software Developer Typescript City London 000 ...
# 2  Travelfusion the world largest travel aggregat...
# 3  LMS deliver Value Small chunk Safely can Enjoy...
# 4  APP 044 Software Developer Apprentice Transfer...
#
#              time_of_scrape               job_search_term  job_location  \
# ...

# %%
clean_SE.nunique()
# Out:
# company                                379
# job_title                              274
# job_descr                              498
# time_of_scrape                         500
# job_search_term                          1
# job_location                             0
# salary_from_page_source_as_stated       74
# salary_from_page_source_conv_hourly     73
# salary_from_page_source_time_period      4
# Num_reviews                            107
# Loc_from_title                         162
# date                                     1
# dtype: int64

# %% [markdown]
# All good, let's save once more and move to analysis!

# %%
clean_SE.loc[clean_SE.job_descr.duplicated()]
clean_SE.loc[clean_SE.company =='TeachKloud']
# Out:
#         company                                 job_title  \
# 59   TeachKloud  Senior Software Developer (Mobile & Web)
# 341  TeachKloud  Senior Software Developer (Mobile & Web)
#
#                                              job_descr  \
# 59   Job briefWe are looking for Remote Full Stack ...
# 341                                                NaN
#
#                time_of_scrape               job_search_term  job_location  \
# 59   Fri Nov 20 10:52:28 2020  title:(software , developer)           NaN
# 341  Fri Nov 20 11:18:44 2020  title:(software , developer)           NaN
#
#      salary_from_page_source_as_stated  salary_from_page_source_conv_hourly  \
# 59                             50000.0                                26.34
# 341                            50000.0                                26.34
#
#     salary_from_page_source_time_period  Num_reviews    Loc_from_title  \
# 59                                    Y          NaN  Northern Ireland
# ...

# %%
clean_SE.drop_duplicates(['job_descr'], inplace=True)
clean_SE.drop(columns=['job_location'], inplace=True)
clean_SE.job_descr.dropna(inplace=True)

# %%
clean_SE.dropna(subset=['job_descr'], inplace=True)
clean_SE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   company                              498 non-null    object
#  1   job_title                            498 non-null    object
#  2   job_descr                            498 non-null    object
#  3   time_of_scrape                       498 non-null    object
#  4   job_search_term                      498 non-null    object
#  5   salary_from_page_source_as_stated    243 non-null    float64
#  6   salary_from_page_source_conv_hourly  243 non-null    float64
#  7   salary_from_page_source_time_period  243 non-null    object
#  8   Num_reviews                          238 non-null    float64
#  9   Loc_from_title                       498 non-null    object
#  10  date                                 498 non-null    object
# ...

# %%
clean_SE.to_csv('../clean_data/final_SE_jobs_clean.csv')
